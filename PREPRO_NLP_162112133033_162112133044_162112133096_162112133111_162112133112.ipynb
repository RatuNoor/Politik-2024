# %%
#Loading libraries
import numpy as np # provides a high-performance multidimensional array and tools for its manipulation
import pandas as pd # for data munging, it contains manipulation tools designed to make data analysis fast and easy
import re # Regular Expressions - useful for extracting information from text
import nltk # Natural Language Tool Kit for symbolic and statistical natural language processing
import spacy # processing and understanding large volumes of text
import string # String module contains some constants, utility function, and classes for string manipulation
import re

# For viz
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from plotly import graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff
from collections import Counter

from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
pd.options.mode.chained_assignment = None

# %%
# import libraries

# data manipulation
import pandas as pd
import numpy as np

# data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# text processing
import re
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
stopwords = set(stopwords.words('english'))

# # pytorch
# import torch
# from torch import nn
# from torch.optim import Adam
# from torch.utils.data import TensorDataset, DataLoader

# sklearn
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.feature_extraction.text import CountVectorizer

# utils
import os
from tqdm import tqdm
tqdm.pandas()
from collections import Counter
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# !pip install indoNLP
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 2.5 MB/s eta 0:00:00
# ...

# %%
# @title cleaning
import re
from indoNLP.preprocessing import replace_slang
from indoNLP.preprocessing import remove_url
from indoNLP.preprocessing import replace_word_elongation
def prepro(text):
    text = re.sub(r'[#@]\w+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = text.lower()
    text = re.sub(r' +', ' ', text).strip()
    return text

# %%
df = pd.read_csv('/content/data_pemilu.csv')
# Out:
#                          created_at               id_str  \
# 0    Sun Nov 26 04:07:42 +0000 2023  1728626559903486438
# 1    Mon Nov 27 07:06:03 +0000 2023  1729033829439189401
# 2    Sat Nov 25 18:19:56 +0000 2023  1728478643196670269
# 3    Wed Nov 29 18:18:33 +0000 2023  1729927844820906145
# 4    Mon Nov 27 07:45:05 +0000 2023  1729043653849702895
# ..                              ...                  ...
# 332  Tue Nov 28 08:37:02 +0000 2023  1729419112596791584
# 333  Sun Nov 26 10:46:13 +0000 2023  1728726847771607263
# 334  Sat Nov 25 14:16:07 +0000 2023  1728417283511664934
# 335  Mon Nov 27 22:11:06 +0000 2023  1729261591030583737
# 336  Sun Nov 26 00:26:55 +0000 2023  1728570996578554331
#
#                                              full_text  quote_count  \
# 0    Putra Anies Mikail Aziz Baswedan dan putri Cak...           13
# 1    Pak Anies dan Cak Imin Menghadiri Acara Deklar...            9
# 2    Nomer 1 Anies Baswedan -Cak Imin https://t.co/...            2
# ...

# %%
# text cleaning

def rm_link(text):
    return re.sub(r'https?://\S+|www\.\S+', '', text)

# handle case like "shut up okay?Im only 10 years old"
# become "shut up okay Im only 10 years old"
def rm_punct2(text):
    # return re.sub(r'[\!\"\#\$\%\&\'\(\)\*\+\,\-\.\/\:\;\<\=\>\?\@\[\\\]\^\_\`\{\|\}\~]', ' ', text)
    return re.sub(r'[\"\#\$\%\&\'\(\)\*\+\/\:\;\<\=\>\@\[\\\]\^\_\`\{\|\}\~]', ' ', text)

def rm_html(text):
    return re.sub(r'<[^>]+>', '', text)

def space_bt_punct(text):
    pattern = r'([.,!?-])'
    s = re.sub(pattern, r' \1 ', text)     # add whitespaces between punctuation
    s = re.sub(r'\s{2,}', ' ', s)        # remove double whitespaces
    return s

def rm_number(text):
    return re.sub(r'\d+', '', text)

def rm_whitespaces(text):
    return re.sub(r' +', ' ', text)

def rm_nonascii(text):
    return re.sub(r'[^\x00-\x7f]', r'', text)

def rm_emoji(text):
    emojis = re.compile(
        '['
        u'\U0001F600-\U0001F64F'  # emoticons
        u'\U0001F300-\U0001F5FF'  # symbols & pictographs
        u'\U0001F680-\U0001F6FF'  # transport & map symbols
        u'\U0001F1E0-\U0001F1FF'  # flags (iOS)
        u'\U00002702-\U000027B0'
        u'\U000024C2-\U0001F251'
        ']+',
        flags=re.UNICODE
    )
    return emojis.sub(r'', text)

def spell_correction(text):
    return re.sub(r'(.)\1+', r'\1\1', text)

def clean_pipeline(text):
    no_link = rm_link(text)
    no_html = rm_html(no_link)
    space_punct = space_bt_punct(no_html)
    no_punct = rm_punct2(space_punct)
    no_number = rm_number(no_punct)
    no_whitespaces = rm_whitespaces(no_number)
    no_nonasci = rm_nonascii(no_whitespaces)
    no_emoji = rm_emoji(no_nonasci)
    spell_corrected = spell_correction(no_emoji)
    return spell_corrected

# %%
# preprocessing
def tokenize(text):
    return word_tokenize(text)

def rm_stopwords(text):
    return [i for i in text if i not in stopwords]

def lemmatize(text):
    lemmatizer = WordNetLemmatizer()
    lemmas = [lemmatizer.lemmatize(t) for t in text]
    # make sure lemmas does not contains sotpwords
    return rm_stopwords(lemmas)

def preprocess_pipeline(text):
    tokens = tokenize(text)
    no_stopwords = rm_stopwords(tokens)
    lemmas = lemmatize(no_stopwords)
    return ' '.join(lemmas)

# %%
df['clean'] = df['full_text'].progress_apply(clean_pipeline)
df['clean'] = df['clean'].progress_apply(preprocess_pipeline)
df.head()
# Out:
# ...
# 100%|██████████| 3596/3596 [00:05<00:00, 673.89it/s]
#           username                                          full_text  \
# 0     undipmenfess  -dips! Lagi melakukan adegan dewasa: menonton ...
# 1  tvindonesiawkwk  masih belom ada meme pemilu 2024 yang bisa nga...
# 2     satriohendri  Pemilu 2024 ini memang ajang pembuktian bahwa ...
# 3     AndiDarwis71  Semoga kecurangan Pilpres pada Pemilu 2024 ini...
# 4       BangPino__  Ayo Sukseskan Pemilu 2024  Yang Ikut  : 3 Yang...
#
#                                                clean
# 0  - dip ! Lagi melakukan adegan dewasa menonton ...
# 1  masih belom ada meme pemilu yang bisa ngalahin...
# 2  Pemilu ini memang ajang pembuktian bahwa Rakya...
# 3  Semoga kecurangan Pilpres pada Pemilu ini tida...
# 4  Ayo Sukseskan Pemilu Yang Ikut Yang Kalah Yang...

# %%
df["processed"] = df["clean"].map(prepro)
for i in range(len(df)):
    df.at[i, 'processed'] = replace_slang(df.at[i, 'processed'])
    df.at[i, 'processed'] = remove_url(df.at[i, 'processed'])
    df.at[i, 'processed'] = replace_word_elongation(df.at[i, 'processed'])

# %%
# @title ambil preprocessed data
processed_data = df[['processed',  'username'] ]
processed_data
# Out:
#                                               processed         username
# 0     dip lagi melakukan adegan dewasa menonton deba...     undipmenfess
# 1     masih belum ada meme pemilu yang bisa mengalah...  tvindonesiawkwk
# 2     pemilu ini memang ajang pembuktian bahwa rakya...     satriohendri
# 3     semoga kecurangan pilpres pada pemilu ini tida...     AndiDarwis71
# 4     ayo sukseskan pemilu yang ikut yang kalah yang...       BangPino__
# ...                                                 ...              ...
# 3591  program juta lapangan kerja baru merupakan tin...         seruanhl
# 3592  se chil ini ternyta pak ganjarpranowo dan prof...         _Umamlik
# 3593  tim ganjar mahfud pasang target salip suara an...          rmol_id
# 3594  ganjar mahfud di real rakyat indonesia percaya...        Mi9aWempy
# 3595  cnnindonesia t tahun bisa digunakan untuk memb...     Ganjaran_app
#
# [3596 rows x 2 columns]

# %% [markdown]
# # senttttimentt

# %%
# !pip install vaderSentiment
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 3.1 MB/s eta 0:00:00
# ...

# %%
import vaderSentiment
# calling SentimentIntensityAnalyzer object
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
# Using polarity scores for knowing the polarity of each text
def sentiment_analyzer_score(sentence):
    score = analyser.polarity_scores(sentence)
    print("{:-<40} {}".format(sentence, str(score)))

# %%
processed_data['scores'] = processed_data['processed'].apply(lambda review: analyser.polarity_scores(review))

processed_data.reset_index(drop=True, inplace=True)
processed_data.head()
# Out:
#                                            processed         username  \
# 0  putra anies mikail aziz baswedan dan putri cak...     Mayapada0812
# 1  pak anies dan cak imin menghadiri acara deklar...  Yurissa_Samosir
# 2                      nomer anies baswedan cak imin         arwidodo
# 3  anies imin kelebihan banyak gagasan amp seguda...        BarBaro5_
# 4  begini saja kalau sih anak presiden itu yang m...    GeiszChalifah
#
#                                               scores
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  {'neg': 0.0, 'neu': 0.927, 'pos': 0.073, 'comp...

# %%
coumpound_list = []
predicts = []
for i in range(len(processed_data)):
    coumpound = processed_data['scores'][i]['compound']
    coumpound_list.append(coumpound)
    if coumpound >= 0:
        predicts.append('positive')
    else:
        predicts.append('negative')

# %%
processed_data['compund'] = coumpound_list
processed_data['pred_sentiment'] = predicts
processed_data
# Out:
#                                              processed         username  \
# 0    putra anies mikail aziz baswedan dan putri cak...     Mayapada0812
# 1    pak anies dan cak imin menghadiri acara deklar...  Yurissa_Samosir
# 2                        nomer anies baswedan cak imin         arwidodo
# 3    anies imin kelebihan banyak gagasan amp seguda...        BarBaro5_
# 4    begini saja kalau sih anak presiden itu yang m...    GeiszChalifah
# ..                                                 ...              ...
# 332  membagikan susu dan makan siang gratis untuk m...    habiburokhman
# 333  tenang saja pak prabowo tenang saja gibran mas...     Minietweets_
# 334  ridwan kamil optimistis prabowo gibran menang ...       Beritasatu
# 335  kaos hari ini meluncur ajibarang n jakarta sem...     Lembayung071
# 336  pak ridwankamil yth prabowo gibran harus menan...       msaid_didu
#
#                                                 scores  compund pred_sentiment
# ...

# %%
# Specify the path and filename for the CSV file
output_file_path = '/content/merge_cleaned.csv'

# Export DataFrame to CSV
processed_data.to_csv(output_file_path, index=False)

# Print a message indicating the successful export
print(f"DataFrame has been successfully exported to {output_file_path}.")
# Out:
# DataFrame has been successfully exported to /content/merge_cleaned.csv.

# %%
# !pip install Levenshtein
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.4/169.4 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 33.2 MB/s eta 0:00:00
# ...

# %%
# @title hapus similiar tweetts
import networkx as nx
import Levenshtein
import random
import itertools

def compare(tweet1, threshold=0.7):
    # compare tweets using Levenshtein distance (or whatever string comparison metric)
    matches = processed_data['processed'].apply(lambda tweet2: (Levenshtein.ratio(tweet1, tweet2) >= threshold))

    # get positive matches
    matches = matches[matches].index.tolist()

    # convert to list of tuples
    return [*zip(iter(matches[:-1]), iter(matches[1:]))]

# create graph objects
nodes = processed_data['processed'].index.tolist()
edges = [*itertools.chain(*processed_data["processed"].apply(compare))]

# create graphs
G = nx.Graph()
G.add_nodes_from(nodes)
G.add_edges_from(edges)

# get connected component indexes
grouped_indexes = [*nx.connected_components(G)]

# get a random choice index from each group
filtered_indexes = [random.choice([*_]) for _ in grouped_indexes]

processed_data.loc[filtered_indexes]
# Out:
#                                               processed         username
# 0     dip lagi melakukan adegan dewasa menonton deba...     undipmenfess
# 1     masih belum ada meme pemilu yang bisa mengalah...  tvindonesiawkwk
# 2     pemilu ini memang ajang pembuktian bahwa rakya...     satriohendri
# 3     semoga kecurangan pilpres pada pemilu ini tida...     AndiDarwis71
# 4     ayo sukseskan pemilu yang ikut yang kalah yang...       BangPino__
# ...                                                 ...              ...
# 3584  hasto menjelaskan kartu sakti itu mencakup jam...         kumparan
# 3586  pantesan generasi muda nu generasi mudanu dekl...  siticeriaselalu
# 3589  ganjar pranowo memperhatikan kurangnya fasilit...          mikuroQ
# 3591  program juta lapangan kerja baru merupakan tin...         seruanhl
# 3595  cnnindonesia t tahun bisa digunakan untuk memb...     Ganjaran_app
#
# [2601 rows x 2 columns]
